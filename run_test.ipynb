# %%
# %run -i mainCV.py --approach 1 --aug allAug --cls allCls
# Out:
# Conduct evaluation using approach 1.
# classifier_name cnn_ep2
# 	dataset_name:  Adiac
# 		augmentator_name:  Random_diag0.5_down0.25_right0.25_each1
# Model already exisits:  C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach1/Adiac/Random_diag0.5_down0.25_right0.25_each1
# 	dataset_name:  ArrowHead
# 		augmentator_name:  Random_diag0.5_down0.25_right0.25_each1
# Model not exisits:  C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach1/ArrowHead/Random_diag0.5_down0.25_right0.25_each1
# iter 0
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach1/ArrowHead/Random_diag0.5_down0.25_right0.25_each1/_itr_0/
# 				DONE
# iter 1
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach1/ArrowHead/Random_diag0.5_down0.25_right0.25_each1/_itr_1/
# 				DONE
# iter 2
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach1/ArrowHead/Random_diag0.5_down0.25_right0.25_each1/_itr_2/
# 				DONE
# iter 3
# ...

# %%
# %run -i mainCV.py --approach 2 --aug allAug --cls allCls
# Out:
# Conduct evaluation using approach 2.
# classifier_name cnn_ep2
# 	dataset_name:  Adiac
# 		augmentator_name:  Random_diag0.5_down0.25_right0.25_each1
# Model not exisits:  C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1
# split1
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1/split1/
# split2
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1/split2/
# split3
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1/split3/
# split4
# C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1/split4/
# Model saved: C:/Users/admin/Desktop/SS/SeSe/results/cnn_ep2/approach2_cv4/Adiac/Random_diag0.5_down0.25_right0.25_each1
# CV DONE!
#    precision  accuracy    recall   duration
# ...
